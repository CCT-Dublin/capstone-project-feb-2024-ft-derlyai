# %% [markdown]
# *Student Full Name: Derly Milded Montealegre Gonzalez
# *Student Number: 2024151
# *Module Title: Statistical Techniques for Data Analysis
# *Assessment Title: CA 1
# *Assessment Due Date: 20 March 2024
# *Date of Submission: 21 April 2024

# %% [markdown]
# # Load Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.preprocessing as preproc
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", message="The least populated class in y has only 1 members")

# %% [markdown]
# # Reading the Data

# %% [markdown]
# Due to the fact that the original csv file had some chinese characters we use latin1 file encoding rather than the default type

# %%
data = pd.read_csv("new1.csv", encoding="latin1")
dtypes = {'columna1': str, 'columna2': float, 'columna3': int}
data.head()
# Out:
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\1515407928.py:1: DtypeWarning: Columns (1,11,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("new1.csv", encoding="latin1")
#                                                  url              id  \
# 0  https://bj.lianjia.com/chengjiao/101084782030....  101085000000.0
# 1  https://bj.lianjia.com/chengjiao/101086012217....  101086000000.0
# 2  https://bj.lianjia.com/chengjiao/101086041636....  101086000000.0
# 3  https://bj.lianjia.com/chengjiao/101086406841....  101086000000.0
# 4  https://bj.lianjia.com/chengjiao/101086920653....  101087000000.0
#
#           Lng        Lat           Cid   tradeTime     DOM  followers  \
# 0  116.475489  40.019520  1.111030e+12  09/08/2016  1464.0        106
# 1  116.453917  39.881534  1.111030e+12  28/07/2016   903.0        126
# 2  116.561978  39.877145  1.111040e+12  11/12/2016  1271.0         48
# 3  116.438010  40.076114  1.111040e+12  30/09/2016   965.0        138
# 4  116.428392  39.886229  1.111030e+12  28/08/2016   927.0        286
#
#    totalPrice  price  ...  buildingType constructionTime renovationCondition  \
# 0       415.0  31680  ...           1.0             2005                   3
# 1       575.0  43436  ...           1.0             2004                   4
# 2      1030.0  52021  ...           4.0             2005                   3
# 3       297.5  22202  ...           1.0             2008                   1
# 4       392.0  48396  ...           4.0             1960                   2
#
#    buildingStructure ladderRatio elevator  fiveYearsProperty subway  district  \
# 0                  6       0.217      1.0                0.0    1.0         7
# 1                  6       0.667      1.0                1.0    0.0         7
# 2                  6       0.500      1.0                0.0    0.0         7
# 3                  6       0.273      1.0                0.0    0.0         6
# 4                  2       0.333      0.0                1.0    1.0         1
#
#    communityAverage
# 0           56021.0
# 1           71539.0
# 2           48160.0
# 3           51238.0
# 4           62588.0
#
# [5 rows x 26 columns]

# %% [markdown]
# Remove columns that do not interfere with my objective

# %%
data.drop('url', axis=1, inplace=True)
data.drop('id', axis=1, inplace=True)
data.drop('floor', axis=1, inplace=True)

# %%
data.info
# Out:
# <bound method DataFrame.info of                Lng        Lat           Cid   tradeTime     DOM  followers  \
# 0       116.475489  40.019520  1.111030e+12  09/08/2016  1464.0        106
# 1       116.453917  39.881534  1.111030e+12  28/07/2016   903.0        126
# 2       116.561978  39.877145  1.111040e+12  11/12/2016  1271.0         48
# 3       116.438010  40.076114  1.111040e+12  30/09/2016   965.0        138
# 4       116.428392  39.886229  1.111030e+12  28/08/2016   927.0        286
# ...            ...        ...           ...         ...     ...        ...
# 239596  116.382021  39.845714  1.111030e+12  07/05/2016     NaN         21
# 239597  116.416888  39.850187  1.111030e+12  23/04/2016     1.0         12
# 239598  116.450093  39.869164  1.111030e+12  16/04/2016     1.0          0
# 239599  116.364028  39.870465  1.111030e+12  11/04/2016     1.0          2
# 239600  116.416888  39.850187  1.111030e+12  10/05/2016     1.0         29
#
#         totalPrice  price  square livingRoom  ... buildingType  \
# 0            415.0  31680  131.00          2  ...          1.0
# 1            575.0  43436  132.38          2  ...          1.0
# 2           1030.0  52021  198.00          3  ...          4.0
# 3            297.5  22202  134.00          3  ...          1.0
# 4            392.0  48396   81.00          2  ...          4.0
# ...            ...    ...     ...        ...  ...          ...
# 239596       236.5  40380   58.57          1  ...          4.0
# 239597       215.0  39091   55.00          2  ...          4.0
# 239598       920.0  57179  160.90          3  ...          4.0
# 239599       260.0  48508   53.60          2  ...          4.0
# 239600       206.0  32390   63.60          2  ...          4.0
#
#         constructionTime renovationCondition  buildingStructure ladderRatio  \
# 0                   2005                   3                  6       0.217
# 1                   2004                   4                  6       0.667
# 2                   2005                   3                  6       0.500
# 3                   2008                   1                  6       0.273
# 4                   1960                   2                  2       0.333
# ...                  ...                 ...                ...         ...
# 239596              2004                   4                  2       0.200
# 239597              1989                   4                  4       0.333
# 239598              2005                   4                  6       0.333
# 239599              1990                   3                  2       0.333
# 239600              1989                   4                  2       0.333
#
#         elevator  fiveYearsProperty  subway  district  communityAverage
# 0            1.0                0.0     1.0         7           56021.0
# 1            1.0                1.0     0.0         7           71539.0
# 2            1.0                0.0     0.0         7           48160.0
# 3            1.0                0.0     0.0         6           51238.0
# 4            0.0                1.0     1.0         1           62588.0
# ...          ...                ...     ...       ...               ...
# 239596       0.0                1.0     1.0         2           56451.0
# 239597       0.0                0.0     1.0         2           50104.0
# 239598       1.0                1.0     1.0         2           82017.0
# 239599       0.0                1.0     0.0         2           62103.0
# 239600       0.0                1.0     1.0         2           50104.0
#
# [239601 rows x 23 columns]>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239601 entries, 0 to 239600
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Lng                  239601 non-null  float64
#  1   Lat                  239601 non-null  float64
#  2   Cid                  239601 non-null  float64
#  3   tradeTime            239601 non-null  object
#  4   DOM                  136722 non-null  float64
#  5   followers            239601 non-null  int64
#  6   totalPrice           239601 non-null  float64
#  7   price                239601 non-null  int64
#  8   square               239601 non-null  float64
#  9   livingRoom           239601 non-null  object
#  10  drawingRoom          239601 non-null  object
#  11  kitchen              239601 non-null  int64
#  12  bathRoom             239601 non-null  object
#  13  buildingType         237801 non-null  float64
#  14  constructionTime     239601 non-null  object
#  15  renovationCondition  239601 non-null  int64
#  16  buildingStructure    239601 non-null  int64
#  17  ladderRatio          239601 non-null  float64
#  18  elevator             239572 non-null  float64
#  19  fiveYearsProperty    239572 non-null  float64
#  20  subway               239572 non-null  float64
#  21  district             239601 non-null  int64
#  22  communityAverage     239311 non-null  float64
# dtypes: float64(12), int64(6), object(5)
# memory usage: 42.0+ MB

# %%
data.describe()
# Out:
#                  Lng            Lat           Cid            DOM  \
# count  239601.000000  239601.000000  2.396010e+05  136722.000000
# mean      116.423981      39.947727  1.135098e+12      33.679591
# std         0.096902       0.096727  2.726411e+12      52.534392
# min       116.072514      39.627030  1.111030e+12       1.000000
# 25%       116.357611      39.885855  1.111030e+12       1.000000
# 50%       116.430435      39.934030  1.111030e+12      13.000000
# 75%       116.477920      40.007545  1.111030e+12      45.000000
# max       116.732378      40.252758  1.114620e+15    1464.000000
#
#            followers     totalPrice          price         square  \
# count  239601.000000  239601.000000  239601.000000  239601.000000
# mean       19.964670     361.716348   44270.253659      84.870276
# std        38.117994     239.726535   22326.981578      38.013975
# min         0.000000       0.100000       1.000000       7.300000
# 25%         1.000000     211.000000   28646.000000      58.560000
# 50%         7.000000     302.000000   38785.000000      76.250000
# 75%        23.000000     440.000000   54087.000000     100.780000
# max      1143.000000   18130.000000  156250.000000    1745.500000
#
#              kitchen   buildingType  renovationCondition  buildingStructure  \
# count  239601.000000  237801.000000        239601.000000       239601.00000
# mean        0.993986       3.000590             2.702138            4.53751
# std         0.114155       1.270988             1.294238            1.87967
# min         0.000000       0.048000             0.000000            0.00000
# 25%         1.000000       1.000000             1.000000            2.00000
# 50%         1.000000       4.000000             3.000000            6.00000
# 75%         1.000000       4.000000             4.000000            6.00000
# max         4.000000       4.000000             4.000000            6.00000
#
#         ladderRatio       elevator  fiveYearsProperty         subway  \
# count  2.396010e+05  239572.000000      239572.000000  239572.000000
# mean   8.393519e+01       0.594068           0.621709       0.618482
# std    2.891864e+04       0.491073           0.484962       0.485760
# min    0.000000e+00       0.000000           0.000000       0.000000
# 25%    2.500000e-01       0.000000           0.000000       0.000000
# 50%    3.330000e-01       1.000000           1.000000       1.000000
# 75%    5.000000e-01       1.000000           1.000000       1.000000
# max    1.000940e+07       1.000000           1.000000       1.000000
#
#             district  communityAverage
# count  239601.000000     239311.000000
# mean        5.898114      60358.299117
# std         2.513226      19125.309388
# min         1.000000      10847.000000
# 25%         4.000000      45933.000000
# 50%         7.000000      57277.000000
# 75%         7.000000      70154.000000
# max        13.000000     183109.000000

# %% [markdown]
# # Missing Data

# %% [markdown]
# # Calculate the number of missing values per variable

# %%
missing_counts = data.isna().sum()
missing_df = pd.DataFrame({'Variable': missing_counts.index, 'Value': missing_counts.values})
missing_df = missing_df[missing_df['Value'] > 0]
missing_df['Percentage'] = missing_df['Value'] / len(data)
missing_df = missing_df.sort_values(by='Percentage', ascending=False)

# %% [markdown]
# # Missing values graph

# %%
plt.figure(figsize=(10, 6))
plt.barh(missing_df['Variable'], missing_df['Percentage'], color='green')
plt.xlabel('Percentage of Missing Values')
plt.ylabel('Variable')
plt.title('Missing Data by Variable')
plt.show()

# %% [markdown]
# I want to better understand the distribution of the data in the 'DOM' column,
# identify possible outliers, evaluate if the variability of the mean is significantly greater than the median,
# and check if the standard deviation is high.

# %%
data['DOM'].describe()
# Out:
# count    136722.000000
# mean         33.679591
# std          52.534392
# min           1.000000
# 25%           1.000000
# 50%          13.000000
# 75%          45.000000
# max        1464.000000
# Name: DOM, dtype: float64

# %% [markdown]
# Using the median of the existing values in the DOM,buildingType,communityAverage column to replace missing values

# %%
import numpy as np
mediana_DOM = np.nanmedian(data['DOM'])
data['DOM'] = np.where(np.isnan(data['DOM']), mediana_DOM, data['DOM'])

# %%
mediana_buildingType = np.nanmedian(data['buildingType'])
data['buildingType'] = np.where(np.isnan(data['buildingType']), mediana_DOM, data['buildingType'])

# %%
mediana_communityAverage = np.nanmedian(data['communityAverage'])
data['communityAverage'] = np.where(np.isnan(data['communityAverage']), mediana_DOM, data['communityAverage'])

# %% [markdown]
# so that they are recognized as missing values and treated appropriately in the resulting DataFrame

# %%
missing_value_formats = ["?","NA","Na","NaN.",".NaN","NaN","nA","na","n.a","n.a.","Î´Öª",".n.a","n/a","nan","--","UnKnown"]
data = pd.read_csv('new1.csv', encoding="latin1", na_values=missing_value_formats)
# Out:
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\325963720.py:2: DtypeWarning: Columns (1,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('new1.csv', encoding="latin1", na_values=missing_value_formats)

# %% [markdown]
# Identifying which columns have missing values

# %%
data.isnull().sum()
# Out:
# url                         0
# id                          0
# Lng                         0
# Lat                         0
# Cid                         0
# tradeTime                   0
# DOM                    102879
# followers                   0
# totalPrice                  0
# price                       0
# square                      0
# livingRoom                  0
# drawingRoom                 0
# kitchen                     0
# bathRoom                    1
# floor                       0
# buildingType             1800
# constructionTime        12323
# renovationCondition         0
# buildingStructure           0
# ladderRatio                 0
# elevator                   29
# fiveYearsProperty          29
# subway                     29
# district                    0
# communityAverage          290
# dtype: int64

# %% [markdown]
# Columns has a missing value (NaN), I replace it with 0

# %%
data["elevator"].fillna(0, inplace=True)         
data["fiveYearsProperty"].fillna(0, inplace=True) 
data["subway"].fillna(0, inplace=True)

# %%
data.isnull().sum()
# Out:
# url                         0
# id                          0
# Lng                         0
# Lat                         0
# Cid                         0
# tradeTime                   0
# DOM                    102879
# followers                   0
# totalPrice                  0
# price                       0
# square                      0
# livingRoom                  0
# drawingRoom                 0
# kitchen                     0
# bathRoom                    1
# floor                       0
# buildingType             1800
# constructionTime        12323
# renovationCondition         0
# buildingStructure           0
# ladderRatio                 0
# elevator                    0
# fiveYearsProperty           0
# subway                      0
# district                    0
# communityAverage          290
# dtype: int64

# %% [markdown]
# # Levels Assignement

# %%
data_copy = data.copy()
building_type_mapping = {1: 'Tower', 2: 'Bungalow', 3: 'Plate/Tower', 4: 'Plate'}
data_copy['buildingType'] = data_copy['buildingType'].replace(building_type_mapping)

# %%
data_copy = data_copy[data_copy['buildingType'].isin(building_type_mapping.values())]
data_copy['buildingType'] = data_copy['buildingType'].astype('category')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data_copy['buildingType'] = data_copy['buildingType'].astype('category')

plt.figure(figsize=(10, 6))
sns.boxplot(data=data_copy, x='buildingType', y='price', palette='viridis')
plt.title('Prices depending on the type of building')
plt.ylabel('Price per square meter')
plt.xlabel('Building type')
plt.show()
# Out:
# C:\Users\monte\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Lng', y='Lat', hue='buildingType', data=data_copy, palette='viridis', s=20, alpha=0.6)
plt.xlabel('Lng')
plt.ylabel('Lat')
plt.title('Data distribution in Beijing by building type')
plt.show()

# %%
building_type_mapping = {1: 'Other', 2: 'Rough', 3: 'Simplicity', 4: 'Hardcover'}
data_copy['renovationCondition'] = data_copy['renovationCondition'].replace(building_type_mapping)

# %%
data_copy = data_copy[data_copy['renovationCondition'].isin(building_type_mapping.values())]
data_copy['renovationCondition'] = data_copy['renovationCondition'].astype('category')

# %%
data_copy['renovationCondition'] = data_copy['renovationCondition'].astype('category')

plt.figure(figsize=(10, 6))
sns.boxplot(data=data_copy, x='renovationCondition', y='price', palette='viridis')
plt.title('price in Function of the renovation Condition')
plt.ylabel('Price Per Sqft')
plt.xlabel('renovation')
plt.show()
# Out:
# C:\Users\monte\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Lng', y='Lat', hue='renovationCondition', data=data_copy, palette='viridis', s=20, alpha=0.6)
plt.xlabel('Lng')
plt.ylabel('Lat')
plt.title('Data distribution in Beijing by renovation Condition')
plt.show()

# %%
building_type_mapping = {1: 'Unavailable', 2: 'Mixed', 3: 'Brick/Wood', 4: 'Brick/Concrete',5:'Steel',6:'Steel/Concrete'}
data_copy['buildingStructure'] = data_copy['buildingStructure'].replace(building_type_mapping)

# %%
data_copy = data_copy[data_copy['buildingStructure'].isin(building_type_mapping.values())]
data_copy['buildingStructure'] = data_copy['buildingStructure'].astype('category')

# %%
data_copy['buildingStructure'] = data_copy['buildingStructure'].astype('category')

plt.figure(figsize=(10, 6))
sns.boxplot(data=data_copy, x='buildingStructure', y='price', palette='viridis')
plt.title('price in Function of the building Structure')
plt.ylabel('Price Per Sqft')
plt.xlabel('buildingStructure')
plt.show()
# Out:
# C:\Users\monte\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Lng', y='Lat', hue='buildingStructure', data=data_copy, palette='viridis', s=20, alpha=0.6)
plt.xlabel('Lng')
plt.ylabel('Lat')
plt.title('Data distribution in Beijing by building Structure')
plt.show()

# %%
building_type_mapping = {1.0: 'Has_elevator', 0.0: 'No_elevator'}
data_copy['elevator'] = data_copy['elevator'].replace(building_type_mapping)

# %%
data_copy['elevator'] = data_copy['elevator'].astype('category')

plt.figure(figsize=(10, 6))
sns.boxplot(data=data_copy, x='elevator', y='price', palette='viridis')
plt.title('price in Function of the elevator')
plt.ylabel('Price Per Sqft')
plt.xlabel('elevator')
plt.show()
# Out:
# C:\Users\monte\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Lng', y='Lat', hue='elevator', data=data_copy, palette='viridis', s=20, alpha=0.6)
plt.xlabel('Lng')
plt.ylabel('Lat')
plt.title('Data distribution in Beijing by elevator')
plt.show()

# %%
building_type_mapping = {1.0: 'Has_subway', 0.0: 'No_subway'}
data_copy['subway'] = data_copy['subway'].replace(building_type_mapping)

# %%
data_copy['subway'] = data_copy['subway'].astype('category')

plt.figure(figsize=(10, 6))
sns.boxplot(data=data_copy, x='subway', y='price', palette='viridis')
plt.title('price in Function of the subway')
plt.ylabel('Price Per Sqft')
plt.xlabel('subway')
plt.show()
# Out:
# C:\Users\monte\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Lng', y='Lat', hue='subway', data=data_copy, palette='viridis', s=20, alpha=0.6)
plt.xlabel('Lng')
plt.ylabel('Lat')
plt.title('Data distribution in Beijing by subway')
plt.show()

# %%
building_type_mapping = {1.0: 'Ownership < 5', 0.0: 'Ownership > 5'}
data_copy['fiveYearsProperty'] = data_copy['fiveYearsProperty'].replace(building_type_mapping)

# %%
data_copy['fiveYearsProperty'] = data_copy['fiveYearsProperty'].astype('category')

plt.figure(figsize=(10, 6))
sns.boxplot(data=data_copy, x='fiveYearsProperty', y='price', palette='viridis')
plt.title('price in Function of the five Years Property')
plt.ylabel('Price Per Sqft')
plt.xlabel('fiveYearsProperty')
plt.show()
# Out:
# C:\Users\monte\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Lng', y='Lat', hue='fiveYearsProperty', data=data_copy, palette='viridis', s=20, alpha=0.6)
plt.xlabel('Lng')
plt.ylabel('Lat')
plt.title('Data distribution in Beijing by five Years Property')
plt.show()

# %%
building_type_mapping = {1: 'DongCheng', 2: 'FengTai', 3: 'DaXing', 4: 'FaXing',5:'FangShang',6:'ChangPing',7:'ChaoYang'
                         ,8:'HaiDian',9:'ShiJingShan',10:'XiCheng',11:'TongZhou',12:'ShunYi',13:'MenTouGou'}
data_copy['district'] = data_copy['district'].replace(building_type_mapping)

# %%
data_copy = data_copy[data_copy['district'].isin(building_type_mapping.values())]
data_copy['district'] = data_copy['district'].astype('category')

# %%
data_copy['district'] = data_copy['district'].astype('category')

plt.figure(figsize=(10, 6))
sns.boxplot(data=data_copy, x='district', y='price', palette='viridis')
plt.title('price in Function of the five Years Property')
plt.ylabel('Price Per Sqft')
plt.xlabel('district')
plt.show()
# Out:
# C:\Users\monte\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Lng', y='Lat', hue='district', data=data_copy, palette='viridis', s=20, alpha=0.6)
plt.xlabel('Lng')
plt.ylabel('Lat')
plt.title('Data distribution in Beijing by district')
plt.show()

# %% [markdown]
# # Conversion of variables

# %%
data2 = data.copy()
group_categorical = ['buildingType','renovationCondition','buildingStructure',
                     'elevator','subway','district']
data2[group_categorical] = data2[group_categorical].astype('category')
data2 = data2[pd.to_numeric(data2['constructionTime'], errors='coerce').notnull()]
data2['constructionTime'] = pd.to_numeric(data2['constructionTime'])

# %% [markdown]
# Calculate the number of missing values per column

# %%
x3 = data2.isna().sum()
missing = pd.DataFrame({'Variable': x3.index, 'Value': x3.values})
missing = missing[missing['Value'] > 0]
missing['Value'] = missing['Value'] / len(data2)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Value', y='Variable', data=missing.sort_values(by='Value', ascending=False),
            color='purple')
plt.xlabel('Porcentaje de valores faltantes')
plt.ylabel('Variable')
plt.title('Percentage of missing values per variable')
plt.show()

# %% [markdown]
# The conversion from build time to numeric value introduced some new NAs, due to the encoding in Latin characters

# %%
summary = data2['constructionTime'].describe()
print(summary)
# Out:
# count    227278.000000
# mean       1999.580641
# std          24.157205
# min           0.000000
# 25%        1995.000000
# 50%        2002.000000
# 75%        2006.000000
# max        2016.000000
# Name: constructionTime, dtype: float64

# %%
data2_without_na = data2.dropna()
data_cleaned = data2_without_na[(data2_without_na['constructionTime'] != 0) & 
                                 (data2_without_na['constructionTime'] != 1)]

# %%
summary = data2['DOM'].describe()
print(summary)
# Out:
# count    131432.000000
# mean         34.242140
# std          52.717469
# min           1.000000
# 25%           1.000000
# 50%          13.000000
# 75%          46.000000
# max        1464.000000
# Name: DOM, dtype: float64

# %%
columnas_con_nan = ['DOM','buildingType','communityAverage','bathRoom']
data3 = data2.dropna(subset=columnas_con_nan)
missing_values_count = data3.isna().sum()
print(missing_values_count)
# Out:
# url                    0
# id                     0
# Lng                    0
# Lat                    0
# Cid                    0
# tradeTime              0
# DOM                    0
# followers              0
# totalPrice             0
# price                  0
# square                 0
# livingRoom             0
# drawingRoom            0
# kitchen                0
# bathRoom               0
# floor                  0
# buildingType           0
# constructionTime       0
# renovationCondition    0
# buildingStructure      0
# ladderRatio            0
# elevator               0
# fiveYearsProperty      0
# subway                 0
# district               0
# communityAverage       0
# dtype: int64

# %% [markdown]
# These columns that are not important for my information

# %%
data3.drop('url', axis=1, inplace=True)
data3.drop('id', axis=1, inplace=True)
data3.drop('floor', axis=1, inplace=True)
# Out:
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\4018131883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.drop('url', axis=1, inplace=True)
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\4018131883.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.drop('id', axis=1, inplace=True)
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\4018131883.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.drop('floor', axis=1, inplace=True)

# %%
print(data3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 130401 entries, 0 to 239600
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Lng                  130401 non-null  float64
#  1   Lat                  130401 non-null  float64
#  2   Cid                  130401 non-null  float64
#  3   tradeTime            130401 non-null  object
#  4   DOM                  130401 non-null  float64
#  5   followers            130401 non-null  int64
#  6   totalPrice           130401 non-null  float64
#  7   price                130401 non-null  int64
#  8   square               130401 non-null  float64
#  9   livingRoom           130401 non-null  object
#  10  drawingRoom          130401 non-null  object
#  11  kitchen              130401 non-null  int64
#  12  bathRoom             130401 non-null  float64
#  13  buildingType         130401 non-null  category
#  14  constructionTime     130401 non-null  float64
#  15  renovationCondition  130401 non-null  category
#  16  buildingStructure    130401 non-null  category
#  17  ladderRatio          130401 non-null  float64
#  18  elevator             130401 non-null  category
#  19  fiveYearsProperty    130401 non-null  float64
#  20  subway               130401 non-null  category
#  21  district             130401 non-null  category
#  22  communityAverage     130401 non-null  float64
# dtypes: category(6), float64(11), int64(3), object(3)
# memory usage: 18.7+ MB
# None

# %% [markdown]
# # Allows us to prepare data for statistical calculations and visualizations

# %%
import pandas as pd
data3['tradeTime'] = pd.to_numeric(data3['tradeTime'], errors='coerce')
data3['livingRoom'] = pd.to_numeric(data3['livingRoom'], errors='coerce')
data3['drawingRoom'] = pd.to_numeric(data3['drawingRoom'], errors='coerce')
data3['buildingType'] = pd.to_numeric(data3['buildingType'], errors='coerce')
data3['renovationCondition'] = pd.to_numeric(data3['renovationCondition'], errors='coerce')
data3['buildingStructure'] = pd.to_numeric(data3['buildingStructure'], errors='coerce')
data3['elevator'] = pd.to_numeric(data3['elevator'], errors='coerce')
data3['subway'] = pd.to_numeric(data3['subway'], errors='coerce')
data3['district'] = pd.to_numeric(data3['district'], errors='coerce')
data3.info()
# Out:
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\941178832.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['tradeTime'] = pd.to_numeric(data3['tradeTime'], errors='coerce')
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\941178832.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['livingRoom'] = pd.to_numeric(data3['livingRoom'], errors='coerce')
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\941178832.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['drawingRoom'] = pd.to_numeric(data3['drawingRoom'], errors='coerce')
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\941178832.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['buildingType'] = pd.to_numeric(data3['buildingType'], errors='coerce')
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\941178832.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['renovationCondition'] = pd.to_numeric(data3['renovationCondition'], errors='coerce')
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\941178832.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['buildingStructure'] = pd.to_numeric(data3['buildingStructure'], errors='coerce')
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\941178832.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['elevator'] = pd.to_numeric(data3['elevator'], errors='coerce')
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\941178832.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['subway'] = pd.to_numeric(data3['subway'], errors='coerce')
# <class 'pandas.core.frame.DataFrame'>
# Index: 130401 entries, 0 to 239600
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Lng                  130401 non-null  float64
#  1   Lat                  130401 non-null  float64
#  2   Cid                  130401 non-null  float64
#  3   tradeTime            0 non-null       float64
#  4   DOM                  130401 non-null  float64
#  5   followers            130401 non-null  int64
#  6   totalPrice           130401 non-null  float64
#  7   price                130401 non-null  int64
#  8   square               130401 non-null  float64
#  9   livingRoom           130378 non-null  float64
#  10  drawingRoom          130378 non-null  float64
#  11  kitchen              130401 non-null  int64
#  12  bathRoom             130401 non-null  float64
#  13  buildingType         130401 non-null  float64
#  14  constructionTime     130401 non-null  float64
#  15  renovationCondition  130401 non-null  int64
#  16  buildingStructure    130401 non-null  int64
#  17  ladderRatio          130401 non-null  float64
#  18  elevator             130401 non-null  float64
#  19  fiveYearsProperty    130401 non-null  float64
#  20  subway               130401 non-null  float64
#  21  district             130401 non-null  int64
#  22  communityAverage     130401 non-null  float64
# dtypes: float64(17), int64(6)
# memory usage: 23.9 MB
# C:\Users\monte\AppData\Local\Temp\ipykernel_17840\941178832.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['district'] = pd.to_numeric(data3['district'], errors='coerce')

# %%
any_nan = data3.isnull().values.any()

# %%
import pandas as pd
nan_count = data.isna().sum()
print(nan_count)
# Out:
# url                         0
# id                          0
# Lng                         0
# Lat                         0
# Cid                         0
# tradeTime                   0
# DOM                    102879
# followers                   0
# totalPrice                  0
# price                       0
# square                      0
# livingRoom                  0
# drawingRoom                 0
# kitchen                     0
# bathRoom                    1
# floor                       0
# buildingType             1800
# constructionTime        12323
# renovationCondition         0
# buildingStructure           0
# ladderRatio                 0
# elevator                    0
# fiveYearsProperty           0
# subway                      0
# district                    0
# communityAverage          290
# dtype: int64

# %% [markdown]
# # Data Exploration

# %% [markdown]
# # Numeric Variables

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
numeric_columns = data3.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_columns.corr()
correlation_matrix = correlation_matrix.drop(['Lng', 'Lat'], axis=1, errors='ignore')
correlation_matrix = correlation_matrix.drop(['Lng', 'Lat'], axis=0, errors='ignore')

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Correlation between numerical variables')
plt.xlabel('Variables')
plt.ylabel('Variables')
plt.show()
# Out:
# C:\Users\monte\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=data3, x='price', color='steelblue', bins=30)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Price')
plt.show()
# Out:
# C:\Users\monte\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
quantiles_teoricos = np.random.normal(loc=0, scale=1, size=len(data3['price']))
price_sorted = np.sort(data3['price'])
quantiles = stats.norm.ppf(np.linspace(0, 1, len(price_sorted)))

# %%
plt.figure(figsize=(8, 6))
plt.scatter(quantiles_teoricos, price_sorted, color='blue', alpha=0.5, label='Q-Q plot')
plt.plot([np.min(quantiles_teoricos), np.max(quantiles_teoricos)], [np.min(price_sorted), np.max(price_sorted)], color='red', label='Linea de ajuste')
plt.xlabel('Theoretical quantiles')
plt.ylabel('Observed quantiles')
plt.title('Column Q-Q Chart "price"')
plt.legend()
plt.show()

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
n = 10  
p = 0.7

# %%
x = np.arange(0, n + 1) 
probabilities = binom.pmf(k=x, n=n, p=p)

# %%
plt.figure(figsize=(10, 5))
plt.bar(x, probabilities, color='blue', width=0.4)
plt.xlabel('Number of successes')
plt.ylabel('Probability')
plt.title('Probability distribution of a binomial random variable')
plt.show()

# %%
quantiles_teoricos = sm.ProbPlot(probabilities).theoretical_quantiles
price_sorted = np.sort(probabilities)
plt.figure(figsize=(8, 6))
plt.scatter(quantiles_teoricos, price_sorted, color='blue', alpha=0.5, label='Q-Q plot')
plt.plot([np.min(quantiles_teoricos), np.max(quantiles_teoricos)], [np.min(price_sorted), np.max(price_sorted)], color='red', label='Línea de ajuste')
plt.xlabel('Theoretical quantiles')
plt.ylabel('Observed quantiles')
plt.title('Q-Q plot of binomial distribution')
plt.legend()
plt.show()

# %%
print(data3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 130401 entries, 0 to 239600
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Lng                  130401 non-null  float64
#  1   Lat                  130401 non-null  float64
#  2   Cid                  130401 non-null  float64
#  3   tradeTime            0 non-null       float64
#  4   DOM                  130401 non-null  float64
#  5   followers            130401 non-null  int64
#  6   totalPrice           130401 non-null  float64
#  7   price                130401 non-null  int64
#  8   square               130401 non-null  float64
#  9   livingRoom           130378 non-null  float64
#  10  drawingRoom          130378 non-null  float64
#  11  kitchen              130401 non-null  int64
#  12  bathRoom             130401 non-null  float64
#  13  buildingType         130401 non-null  float64
#  14  constructionTime     130401 non-null  float64
#  15  renovationCondition  130401 non-null  int64
#  16  buildingStructure    130401 non-null  int64
#  17  ladderRatio          130401 non-null  float64
#  18  elevator             130401 non-null  float64
#  19  fiveYearsProperty    130401 non-null  float64
#  20  subway               130401 non-null  float64
#  21  district             130401 non-null  int64
#  22  communityAverage     130401 non-null  float64
# dtypes: float64(17), int64(6)
# memory usage: 23.9 MB
# None

# %%
nan_count = data.isna().sum()
print(nan_count)
# Out:
# url                         0
# id                          0
# Lng                         0
# Lat                         0
# Cid                         0
# tradeTime                   0
# DOM                    102879
# followers                   0
# totalPrice                  0
# price                       0
# square                      0
# livingRoom                  0
# drawingRoom                 0
# kitchen                     0
# bathRoom                    1
# floor                       0
# buildingType             1800
# constructionTime        12323
# renovationCondition         0
# buildingStructure           0
# ladderRatio                 0
# elevator                    0
# fiveYearsProperty           0
# subway                      0
# district                    0
# communityAverage          290
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = data3.drop('price', axis=1)
y = data3['price']

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
imputer = SimpleImputer(strategy='mean')
scaler = StandardScaler()

# %%
X_imputed = imputer.fit_transform(X)
X_scaled = scaler.fit_transform(X_imputed)

# %%
train_sizes = [0.2, 0.25, 0.3]
train_size_names = [f"Train Size {int(size * 100)}%" for size in train_sizes]
accuracies = []

# %%
for train_size in train_sizes:
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=1 - train_size, random_state=42)
    print(train_size_names)
# Out:
# ['Train Size 20%', 'Train Size 25%', 'Train Size 30%']
# ['Train Size 20%', 'Train Size 25%', 'Train Size 30%']
# ['Train Size 20%', 'Train Size 25%', 'Train Size 30%']

# %%
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=test_size, random_state=42)

# %%
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
accuracies = [] 

for train_size in train_sizes:
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=1 - train_size, random_state=42)
    classifier = GaussianNB()
    classifier.fit(X_train, y_train)
    accuracy = cross_val_score(classifier, X_train, y_train, cv=5).mean()
    accuracies.append(accuracy)

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, accuracies, marker='o')
plt.title('Model accuracy vs. Training set size')
plt.xlabel('Training set size')
plt.ylabel('Cross-validated accuracy')
plt.xticks(train_sizes, labels=[f'{int(size * 100)}%' for size in train_sizes])
plt.grid(True)
plt.show()

# %% [markdown]
# Regression Line

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming train_sizes and accuracies are lists or numpy arrays of numbers
train_sizes = np.array(train_sizes)  
accuracies = np.array(accuracies)

# Calculate the regression line
slope, intercept = np.polyfit(train_sizes, accuracies, 1)
regression_line = slope * train_sizes + intercept

# Plot the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(train_sizes, accuracies, marker='o')

# Add the regression line
plt.plot(train_sizes, regression_line, color='red', label='Regression Line')

plt.title('Model accuracy vs. Training set size')
plt.xlabel('Training set size')
plt.ylabel('Cross-validated accuracy')


plt.xticks(train_sizes, labels=[f'{int(size * 100)}%' for size in train_sizes])

plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Reference

# %% [markdown]
# Housing price of Beijing from 2011 to 2017, fetching from https://www.kaggle.com/datasets/ruiqurm/lianjia
#
# Alberca, A. S. (2020, October 4). La librería Matplotlib | Aprende con Alf.
# Aprende Con Alf. https://aprendeconalf.es/docencia/python/manual/matplotlib/
#
# Kuzminska, O. (2021). Selecting tools to enhance scholarly communication through the life cycle of scientific research. Educational Technology Quarterly, 2021(3), 402–414. https://doi.org/10.55056/etq.19
